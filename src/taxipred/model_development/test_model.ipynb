# %% [markdown]
# # Testing ML model

# %%
import joblib

t_model = joblib.load("LM_model.joblib")
t_model

# %%
import pandas as pd

#imagine I have measured my data model
sample_test_data  = pd.DataFrame(
    {
    "Trip_Distance_km":[40],
    "Trip_Duration_Minutes":[85],
    "Passenger_Count":[3],
    "Time_of_Day": "Evening"
        
    }
) 

sample_test_data

# %%
t_model.predict(sample_test_data)
