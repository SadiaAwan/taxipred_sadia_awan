# %% [markdown]
# # Testing ML model

# %%
import joblib

t_model = joblib.load("LM_model.joblib")
t_model
# Out:
# {'model': LinearRegression(),
#  'scaler': MinMaxScaler(),
#  'features': ['Trip_Distance_km',
#   'Trip_Duration_Minutes',
#   'Passenger_Count',
#   'Time_of_Day_Evening',
#   'Time_of_Day_Morning',
#   'Time_of_Day_Night']}
